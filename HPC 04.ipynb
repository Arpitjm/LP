# %%
HPC 4
# !pip install cupy-cuda11x
# Out:
# Collecting cupy-cuda11x
#   Downloading cupy_cuda11x-12.3.0-cp38-cp38-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy<1.29,>=1.20 in c:\users\arpit\appdata\local\programs\python\python38\lib\site-packages (from cupy-cuda11x) (1.24.3)
# Collecting fastrlock>=0.5 (from cupy-cuda11x)
#   Downloading fastrlock-0.8.3-cp38-cp38-win_amd64.whl.metadata (7.9 kB)
# Downloading cupy_cuda11x-12.3.0-cp38-cp38-win_amd64.whl (70.2 MB)
#    ---------------------------------------- 0.0/70.2 MB ? eta -:--:--
#    ---------------------------------------- 0.8/70.2 MB 4.8 MB/s eta 0:00:15
#    - -------------------------------------- 1.8/70.2 MB 4.8 MB/s eta 0:00:15
#    - -------------------------------------- 2.6/70.2 MB 4.4 MB/s eta 0:00:16
#    - -------------------------------------- 3.1/70.2 MB 4.9 MB/s eta 0:00:14
#    -- ------------------------------------- 3.9/70.2 MB 3.8 MB/s eta 0:00:18
#    -- ------------------------------------- 5.2/70.2 MB 4.6 MB/s eta 0:00:15
#    --- ------------------------------------ 6.3/70.2 MB 4.6 MB/s eta 0:00:14
#    --- ------------------------------------ 6.3/70.2 MB 4.6 MB/s eta 0:00:14
#    ---- ----------------------------------- 7.9/70.2 MB 4.2 MB/s eta 0:00:15
#    ---- ----------------------------------- 8.4/70.2 MB 4.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 8.9/70.2 MB 4.0 MB/s eta 0:00:16
#    ----- ---------------------------------- 9.4/70.2 MB 4.0 MB/s eta 0:00:16
#    ----- ---------------------------------- 10.5/70.2 MB 4.0 MB/s eta 0:00:15
#    ------ --------------------------------- 11.0/70.2 MB 3.8 MB/s eta 0:00:16
#    ------ --------------------------------- 11.5/70.2 MB 3.9 MB/s eta 0:00:15
#    ------ --------------------------------- 11.5/70.2 MB 3.9 MB/s eta 0:00:15
#    ------ --------------------------------- 11.5/70.2 MB 3.9 MB/s eta 0:00:15
#    ------- -------------------------------- 12.8/70.2 MB 3.4 MB/s eta 0:00:17
#    -------- ------------------------------- 14.2/70.2 MB 3.6 MB/s eta 0:00:16
#    -------- ------------------------------- 14.9/70.2 MB 3.6 MB/s eta 0:00:16
#    -------- ------------------------------- 15.7/70.2 MB 3.7 MB/s eta 0:00:15
#    -------- ------------------------------- 15.7/70.2 MB 3.7 MB/s eta 0:00:15
#    --------- ------------------------------ 16.8/70.2 MB 3.5 MB/s eta 0:00:16
#    ---------- ----------------------------- 17.8/70.2 MB 3.6 MB/s eta 0:00:15
#    ---------- ----------------------------- 18.1/70.2 MB 3.5 MB/s eta 0:00:16
#    ---------- ----------------------------- 18.9/70.2 MB 3.5 MB/s eta 0:00:15
#    ----------- ---------------------------- 19.9/70.2 MB 3.5 MB/s eta 0:00:15
#    ----------- ---------------------------- 21.0/70.2 MB 3.6 MB/s eta 0:00:14
#    ------------ --------------------------- 21.8/70.2 MB 3.6 MB/s eta 0:00:14
#    ------------ --------------------------- 22.0/70.2 MB 3.6 MB/s eta 0:00:14
#    ---------------------------- ----------- 50.3/70.2 MB 3.5 MB/s eta 0:00:06
#    ---------------------------- ----------- 50.6/70.2 MB 3.4 MB/s eta 0:00:06
#    ----------------------------- ---------- 51.6/70.2 MB 3.4 MB/s eta 0:00:06
#    ----------------------------- ---------- 52.4/70.2 MB 3.5 MB/s eta 0:00:06
#    ------------------------------ --------- 53.5/70.2 MB 3.5 MB/s eta 0:00:05
#    ------------------------------ --------- 53.5/70.2 MB 3.5 MB/s eta 0:00:05
#    ------------------------------ --------- 54.3/70.2 MB 3.4 MB/s eta 0:00:05
#    ------------------------------- -------- 55.1/70.2 MB 3.4 MB/s eta 0:00:05
#    -------------------------------- ------- 56.4/70.2 MB 3.5 MB/s eta 0:00:04
#    -------------------------------- ------- 56.6/70.2 MB 3.5 MB/s eta 0:00:04
#    -------------------------------- ------- 56.6/70.2 MB 3.5 MB/s eta 0:00:04
#    -------------------------------- ------- 56.6/70.2 MB 3.5 MB/s eta 0:00:04
#    -------------------------------- ------- 57.4/70.2 MB 3.4 MB/s eta 0:00:04
#    --------------------------------- ------ 58.7/70.2 MB 3.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 59.8/70.2 MB 3.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 60.0/70.2 MB 3.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 60.8/70.2 MB 3.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 61.9/70.2 MB 3.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 62.1/70.2 MB 3.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 62.9/70.2 MB 3.4 MB/s eta 0:00:03
#    ------------------------------------ --- 64.0/70.2 MB 3.4 MB/s eta 0:00:02
#    ------------------------------------ --- 64.5/70.2 MB 3.4 MB/s eta 0:00:02
#    ------------------------------------- -- 65.5/70.2 MB 3.4 MB/s eta 0:00:02
#    ------------------------------------- -- 66.3/70.2 MB 3.4 MB/s eta 0:00:02
#    -------------------------------------- - 67.6/70.2 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 68.2/70.2 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 68.2/70.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  69.2/70.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  70.0/70.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 70.2/70.2 MB 3.4 MB/s eta 0:00:00
# Downloading fastrlock-0.8.3-cp38-cp38-win_amd64.whl (37 kB)
# Installing collected packages: fastrlock, cupy-cuda11x
# Successfully installed cupy-cuda11x-12.3.0 fastrlock-0.8.3
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
USE_GPU = False

if USE_GPU:
    import cupy as xp
else:
    import numpy as xp

# User Input
N = int(input("Enter size of vector/matrix (N): "))

# Input Vectors
print("Enter elements for Vector A:")
A = xp.array([int(input(f"A[{i}]: ")) for i in range(N)])
print("Enter elements for Vector B:")
B = xp.array([int(input(f"B[{i}]: ")) for i in range(N)])

# Vector Addition
C = A + B

print("\nVector A:", A)
print("Vector B:", B)
print("Addition (A + B):", C)

# Input Matrices
print("\nEnter elements for Matrix D:")
D = xp.zeros((N, N), dtype=int)
for i in range(N):
    for j in range(N):
        D[i, j] = int(input(f"D[{i}][{j}]: "))

print("Enter elements for Matrix E:")
E = xp.zeros((N, N), dtype=int)
for i in range(N):
    for j in range(N):
        E[i, j] = int(input(f"E[{i}][{j}]: "))

# Matrix Multiplication
F = D @ E

print("\nMatrix D:")
print(D)

print("\nMatrix E:")
print(E)

print("\nMultiplication Result (D x E):")
print(F)
# Out:
# Enter elements for Vector A:
# Enter elements for Vector B:
#
# Vector A: [1 2 3]
# Vector B: [4 5 6]
# Addition (A + B): [5 7 9]
#
# Enter elements for Matrix D:
# Enter elements for Matrix E:
#
# Matrix D:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
#
# Matrix E:
# [[9 8 7]
#  [6 5 4]
#  [3 2 1]]
#
# Multiplication Result (D x E):
# [[ 30  24  18]
#  [ 84  69  54]
#  [138 114  90]]
